# %% [markdown]
# # Centrality

# %% [markdown]
# ### Degree Centrality

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()
# G.add_edges_from([('c', 'a'), ('a', 'b'), ('b', 'd'), ('d', 'e'), ('e', 'g'), ('e', 'f')])
with open("graph1.txt", "r") as file:
    for line in file:
        edge = line.strip().split()
        if len(edge) == 2:
            G.add_edge(edge[0], edge[1])

# Compute degree centrality
degree_centrality = nx.degree_centrality(G)
print("Degree Centrality:", degree_centrality)

# Rank nodes by degree centrality
ranked_nodes = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  #
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by degree centrality:")
print(rankings)

# Draw the graph
nx.draw(G, with_labels=True, node_color='lightblue', node_size=700, font_size=10)
plt.show()
# Out:
# Degree Centrality: {'a': 0.3333333333333333, 'c': 0.16666666666666666, 'b': 0.3333333333333333, 'd': 0.3333333333333333, 'e': 0.5, 'g': 0.16666666666666666, 'f': 0.16666666666666666}
# Nodes ranked by degree centrality:
# {'e': 1, 'a': 2, 'b': 2, 'd': 2, 'c': 3, 'g': 3, 'f': 3}

# %% [markdown]
# ### Eigen Vector Centrality

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()
with open("graph1.txt", "r") as file:
    for line in file:
        edge = line.strip().split()
        if len(edge) == 2:
            G.add_edge(edge[0], edge[1])
# G.add_edges_from([('a','b'),('b','c')])

# Compute eigenVector
eigenVector = nx.eigenvector_centrality(G)
print("EigenVector Centrality:", eigenVector)

# Rank nodes by eigenVector
ranked_nodes = sorted(eigenVector.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  #
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by EigenVector Centrality:")
print(rankings)

# Draw the graph
nx.draw(G, with_labels=True, node_color='lightblue', node_size=700, font_size=10)
plt.show()
# Out:
# EigenVector Centrality: {'a': 0.28868211241951935, 'c': 0.14943417943250573, 'b': 0.408253224516121, 'd': 0.499999999963481, 'e': 0.5576726017023999, 'g': 0.2886716456508355, 'f': 0.2886716456508355}
# Nodes ranked by EigenVector Centrality:
# {'e': 1, 'd': 2, 'b': 3, 'a': 4, 'g': 5, 'f': 5, 'c': 6}

# %% [markdown]
# ### Katz Centrality

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()
# with open("graph1.txt", "r") as file:
#     for line in file:
#         edge = line.strip().split()
#         if len(edge) == 2:
#             G.add_edge(edge[0], edge[1])

G.add_edges_from([('a','b'),('a','c'),('a','d'),('b','c'),('b','d'),('b','e'),('c','d'),('c','e')])
# Compute katz centrality
katz_centrality = nx.katz_centrality(G)
print("Katz Centrality:", katz_centrality)

# Rank nodes by katz centrality
ranked_nodes = sorted(katz_centrality.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  #
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by katz centrality:")
print(rankings)

# Draw the graph
nx.draw(G, with_labels=True, node_color='lightblue', node_size=700, font_size=10)
plt.show()
# Out:
# Katz Centrality: {'a': 0.44062436633194485, 'b': 0.47667544385428146, 'c': 0.47667544385428146, 'd': 0.44062436633194485, 'e': 0.39656194729422983}
# Nodes ranked by katz centrality:
# {'b': 1, 'c': 1, 'a': 2, 'd': 2, 'e': 3}

# %% [markdown]
# ### Page Rank

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()
# with open("graph1.txt", "r") as file:
#     for line in file:
#         edge = line.strip().split()
#         if len(edge) == 2:
#             G.add_edge(edge[0], edge[1])

G.add_edges_from([('a','b'),('a','e'),('a','d'),('b','c'),('b','e'),('c','d'),('c','e')])

# Compute pagerank
pagerank = nx.pagerank(G)
print("pagerank:", pagerank)

# Rank nodes by pagerank
ranked_nodes = sorted(pagerank.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  #
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by pagerank:")
print(rankings)

# Draw the graph
nx.draw(G, with_labels=True, node_color='lightblue', node_size=700, font_size=10)
plt.show()
# Out:
# pagerank: {'a': 0.21366050844932935, 'b': 0.2108020060443234, 'e': 0.2108020060443234, 'd': 0.15107497101269424, 'c': 0.21366050844932935}
# Nodes ranked by pagerank:
# {'a': 1, 'c': 1, 'b': 2, 'e': 2, 'd': 3}

# %% [markdown]
# ### Betweenness Centrality

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()
with open("graph1.txt", "r") as file:
    for line in file:
        edge = line.strip().split()
        if len(edge) == 2:
            G.add_edge(edge[0], edge[1])

# Compute betweenness
betweenness = nx.betweenness_centrality(G)
print("Betweenness Centrality:", betweenness)

# Rank nodes by betweenness
ranked_nodes = sorted(betweenness.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  #
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by Betweenness Centrality:")
print(rankings)

# Draw the graph
nx.draw(G, with_labels=True, node_color='lightblue', node_size=700, font_size=10)
plt.show()
# Out:
# Betweenness Centrality: {'a': 0.3333333333333333, 'c': 0.0, 'b': 0.5333333333333333, 'd': 0.6, 'e': 0.6, 'g': 0.0, 'f': 0.0}
# Nodes ranked by Betweenness Centrality:
# {'d': 1, 'e': 1, 'b': 2, 'a': 3, 'c': 4, 'g': 4, 'f': 4}

# %% [markdown]
# ### Closeness Centrality

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()
with open("graph1.txt", "r") as file:
    for line in file:
        edge = line.strip().split()
        if len(edge) == 2:
            G.add_edge(edge[0], edge[1])

# Compute closeness
closeness = nx.closeness_centrality(G)
print("closeness Centrality:", closeness)

# Rank nodes by closeness
ranked_nodes = sorted(closeness.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  #
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by closeness Centrality:")
print(rankings)

# Draw the graph
nx.draw(G, with_labels=True, node_color='lightblue', node_size=700, font_size=10)
plt.show()
# Out:
# closeness Centrality: {'a': 0.4, 'c': 0.3, 'b': 0.5, 'd': 0.5454545454545454, 'e': 0.5, 'g': 0.35294117647058826, 'f': 0.35294117647058826}
# Nodes ranked by closeness Centrality:
# {'d': 1, 'b': 2, 'e': 2, 'a': 3, 'g': 4, 'f': 4, 'c': 5}

# %% [markdown]
# ### K-Shell Centrality

# %%
import networkx as nx
import matplotlib.pyplot as plt

def min_degree(G):
    return min(G.degree, key=lambda x: x[1])[1]

def create_bucket(G, degree):
    return [node for node in G.nodes if G.degree(node) == degree]

def remove_nodes(G, degree):
    nodes_to_remove = [node for node in G.nodes if G.degree(node) == degree]
    G.remove_nodes_from(nodes_to_remove)
    return G

def k_shell_centrality(G):
    dictionary_ans = {}
    prev_min_deg = -1
    while len(G.nodes) > 0:
        min_deg = min_degree(G)
        print(min_deg)
        bucket = create_bucket(G, min_deg)
        print(bucket)
        prev_min_deg = max(min_deg, prev_min_deg)
        
        if prev_min_deg not in dictionary_ans:
            dictionary_ans[prev_min_deg] = []
        
        dictionary_ans[prev_min_deg].extend(bucket)
        G = remove_nodes(G, min_deg)
    return dictionary_ans

G = nx.Graph()
G.add_edges_from(
    [(1, 2), (1, 9), (3, 13), (4, 6),
     (5, 6), (5, 7), (5, 8), (5, 9), 
     (5, 10), (5, 11), (5, 12), (10, 12), 
     (10, 13), (11, 14), (12, 14), 
     (12, 15), (13, 14), (13, 15), 
     (13, 17), (14, 15), (15, 16)]
)

k_shell_result = k_shell_centrality(G.copy())

print("K-Shell Centrality Result:")
# for k, nodes in k_shell_result.items():
#     print(f"Shell {k}: Nodes {nodes}")
print(k_shell_result)

nx.draw(G, with_labels=True, node_color='red', node_size=700, font_size=10)
plt.show()
# Out:
# 1
# [2, 3, 4, 7, 8, 17, 16]
# 1
# [1, 6]
# 1
# [9]
# 2
# [11]
# 2
# [5]
# 2
# [10]
# 2
# [13, 12]
# 1
# [14, 15]
# K-Shell Centrality Result:
# {1: [2, 3, 4, 7, 8, 17, 16, 1, 6, 9], 2: [11, 5, 10, 13, 12, 14, 15]}

# %% [markdown]
# ### STC Centrality

# %%
import networkx as nx
from collections import deque
import matplotlib.pyplot as plt

def bfs_upto_level(graph, start_node, max_level):
    visited = set()
    result = []
    queue = deque([(start_node, 0)])
    
    while queue:
        node, level = queue.popleft()
        
        if level > max_level:
            break
        
        if node not in visited:
            visited.add(node)
            result.append((node, level))
            
            for neighbor in graph.neighbors(node):
                if neighbor not in visited:
                    queue.append((neighbor, level + 1))
    
    return result

def total_triangles_in_bfs(graph, start_node, max_level):
    nodes_in_bfs = bfs_upto_level(graph, start_node, max_level)
    # print(start_node+' has nodes : ',nodes_in_bfs)
    triangles = nx.triangles(graph)  
    total = 0
    
    for node, level in nodes_in_bfs:
        total += triangles[node] / pow(2, level+1) 
    
    return total

def stcCentrality(graph):
    centrality = {}
    for node in graph.nodes():
        centrality[node] = total_triangles_in_bfs(graph, node, 3)  
    return centrality

G = nx.Graph()

# G.add_edges_from([(0, 1), (1, 2), (2, 0), (3, 1), (2,3)])
with open("graph2.txt", "r") as file:
    for line in file:
        edge = line.strip().split()
        if len(edge) == 2:
            G.add_edge(edge[0], edge[1])


ans=stcCentrality(G);
print('STC Centrality : ',ans)

ranked_nodes = sorted(ans.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by STC Centrality:")
print(rankings)


nx.draw(G, with_labels=True, node_color='lightblue', node_size=500, font_size=15)
plt.show()
# Out:
# STC Centrality :  {'a': 6.375, 'b': 6.25, 'c': 5.5, 'd': 5.875, 'h': 3.6875, 'g': 3.6875, 'i': 3.1875, 'j': 3.1875, 'e': 4.25, 'k': 2.125, 'l': 2.125, 'f': 4.0, 'm': 1.9375, 'n': 1.9375, 'o': 0.6875, 'p': 2.75, 'q': 1.25, 'x': 0.1875, 'w': 0.1875, 'v': 0.1875, 'u': 0.1875, 't': 0.1875, 'y': 0.1875, 's': 0.1875, 'r': 0.1875}
# Nodes ranked by STC Centrality:
# {'a': 1, 'b': 2, 'd': 3, 'c': 4, 'e': 5, 'f': 6, 'h': 7, 'g': 7, 'i': 8, 'j': 8, 'p': 9, 'k': 10, 'l': 10, 'm': 11, 'n': 11, 'q': 12, 'o': 13, 'x': 14, 'w': 14, 'v': 14, 'u': 14, 't': 14, 'y': 14, 's': 14, 'r': 14}

# %%
import networkx as nx
from collections import deque
import matplotlib.pyplot as plt

def bfs_upto_level(graph, start_node, max_level):
    visited = set()
    result = []
    queue = deque([(start_node, 0)])
    
    while queue:
        node, level = queue.popleft()
        
        if level > max_level:
            break
        
        if node not in visited:
            visited.add(node)
            result.append((node, level))
            
            for neighbor in graph.neighbors(node):
                if neighbor not in visited:
                    queue.append((neighbor, level + 1))
    
    return result

def total_triangles_in_bfs(graph, start_node, max_level):
    nodes_in_bfs = bfs_upto_level(graph, start_node, max_level)
    # print(start_node+' has nodes : ',nodes_in_bfs)
    triangles = nx.triangles(graph)  
    total = 0
    
    for node, level in nodes_in_bfs:
        total += triangles[node] / pow(2, level+1) 
    
    return total

def stcCentrality(graph):
    centrality = {}
    for node in graph.nodes():
        centrality[node] = total_triangles_in_bfs(graph, node, 3)  
    return centrality

G = nx.Graph()

# G.add_edges_from([(0, 1), (1, 2), (2, 0), (3, 1), (2,3)])
with open("graph3.txt", "r") as file:
    for line in file:
        edge = line.strip().split()
        if len(edge) == 2:
            G.add_edge(edge[0], edge[1])

ans=stcCentrality(G);
print('STC Centrality : ',ans)

ranked_nodes = sorted(ans.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by STC Centrality:")
print(rankings)

nx.draw(G, with_labels=True, node_color='lightblue', node_size=500, font_size=15)
plt.show()
# Out:
# STC Centrality :  {'a': 6.375, 'b': 6.25, 'c': 5.5, 'd': 5.875, 'h': 3.6875, 'g': 3.6875, 'e': 4.25, 'f': 4.0, 'p': 2.75, 'q': 1.25, 'x': 0.1875, 'w': 0.1875, 'v': 0.1875, 'u': 0.1875, 't': 0.1875, 'k': 1.0, 'l': 0.5, 'm': 0.5, 'i': 1.0, 'j': 1.0, 'n': 0.0, 'o': 0.0}
# Nodes ranked by STC Centrality:
# {'a': 1, 'b': 2, 'd': 3, 'c': 4, 'e': 5, 'f': 6, 'h': 7, 'g': 7, 'p': 8, 'q': 9, 'k': 10, 'i': 10, 'j': 10, 'l': 11, 'm': 11, 'x': 12, 'w': 12, 'v': 12, 'u': 12, 't': 12, 'n': 13, 'o': 13}

# %% [markdown]
# ### K-Sum Centrality

# %%
import networkx as nx
from collections import deque
import matplotlib.pyplot as plt

def bfs_upto_level(graph, start_node, max_level):
    visited = set()
    result = []
    queue = deque([(start_node, 0)])
    
    while queue:
        node, level = queue.popleft()
        
        if level > max_level:
            break
        
        if node not in visited:
            visited.add(node)
            result.append((node, level))
            
            for neighbor in graph.neighbors(node):
                if neighbor not in visited:
                    queue.append((neighbor, level + 1))
    
    return result

def total_degree_in_bfs(graph, start_node, max_level):
    nodes_in_bfs = bfs_upto_level(graph, start_node, max_level)
    total = 0
    
    for node, level in nodes_in_bfs:
        total += graph.degree(node)
    
    return total

def ksumCentrality(graph):
    centrality = {}
    for node in graph.nodes():
        centrality[node] = total_degree_in_bfs(graph, node, 2)  
    return centrality

G = nx.Graph()

# G.add_edges_from([(0, 1), (1, 2), (2, 0), (3, 1), (2,3)])
with open("graph2.txt", "r") as file:
    for line in file:
        edge = line.strip().split()
        if len(edge) == 2:
            G.add_edge(edge[0], edge[1])



ans=ksumCentrality(G)
print('KSum Centrality : ',ans)

ranked_nodes = sorted(ans.items(), key=lambda x: x[1], reverse=True)

rankings = {}
rank = 1
prev_centrality = None

for node, centrality in ranked_nodes:
    if prev_centrality is not None and centrality != prev_centrality:
        rank += 1
    
    rankings[node] = rank  
    prev_centrality = centrality

# Print the rankings
print("Nodes ranked by KSum Centrality:")
print(rankings)

nx.draw(G, with_labels=True, node_color='red', node_size=500, font_size=15)
plt.show()
# Out:
# KSum Centrality :  {'a': 39, 'b': 42, 'c': 46, 'd': 40, 'h': 31, 'g': 31, 'i': 31, 'j': 31, 'e': 37, 'k': 19, 'l': 19, 'f': 33, 'm': 16, 'n': 17, 'o': 7, 'p': 40, 'q': 23, 'x': 19, 'w': 19, 'v': 19, 'u': 19, 't': 19, 'y': 19, 's': 19, 'r': 19}
# Nodes ranked by KSum Centrality:
# {'c': 1, 'b': 2, 'd': 3, 'p': 3, 'a': 4, 'e': 5, 'f': 6, 'h': 7, 'g': 7, 'i': 7, 'j': 7, 'q': 8, 'k': 9, 'l': 9, 'x': 9, 'w': 9, 'v': 9, 'u': 9, 't': 9, 'y': 9, 's': 9, 'r': 9, 'n': 10, 'm': 11, 'o': 12}

# %% [markdown]
# ### NGSC Centrality

# %%
import networkx as nx
import matplotlib.pyplot as plt

def min_degree(G):
    return min(G.degree, key=lambda x: x[1])[1]

def create_bucket(G, degree):
    return [node for node in G.nodes if G.degree(node) == degree]

def remove_nodes(G, degree):
    nodes_to_remove = [node for node in G.nodes if G.degree(node) == degree]
    G.remove_nodes_from(nodes_to_remove)
    return G

def k_shell_centrality(G):
    dictionary_ans = {}
    prev_min_deg = -1

    while len(G.nodes) > 0:
        min_deg = min_degree(G)
        bucket = create_bucket(G, min_deg)
        prev_min_deg = max(min_deg, prev_min_deg)

        if prev_min_deg not in dictionary_ans:
            dictionary_ans[prev_min_deg] = []

        dictionary_ans[prev_min_deg].extend(bucket)
        G = remove_nodes(G, min_deg)

    return dictionary_ans

def findKSchellValue(my_dict, target):
    for key, values in my_dict.items():
        if target in values:
            return key
    return None 

# Function to compute NGSC for all nodes
def findNGSC(G, tone1, tone2):
    kShell = k_shell_centrality(G.copy()) 
    ans = {}

    for node in G.nodes():
        result = 0
        k_shell_value = findKSchellValue(kShell, node)
        result += (tone1 * (k_shell_value if k_shell_value is not None else 0) + tone2 * G.degree(node))

        for neighborNode in G.neighbors(node):
            k_shell_value_neigh = findKSchellValue(kShell, neighborNode)
            result += (tone1 * (k_shell_value_neigh if k_shell_value_neigh is not None else 0) + tone2 * G.degree(neighborNode))

        ans[node] = result

    return ans

G = nx.Graph()

with open("ca-HepTh.txt", "r") as file:
    for line in file:
        edge = line.strip().split()
        if len(edge) == 2:
            G.add_edge((edge[0]),(edge[1]))  

tone1 = 0.3
tone2 = 0.7

ngsc_values = findNGSC(G, tone1, tone2)
print("NGSC Values:", ngsc_values)

nx.draw(G, with_labels=True, node_color='lightblue', node_size=500, font_size=15)
plt.show()

y=list(ngsc_values.values())
x=list(ngsc_values.keys())
plt.plot(x,y)
plt.xlabel('Nodes')
plt.ylabel('NGSC Values')
plt.show()

plt.scatter(x, y)
plt.xlabel('Nodes')
plt.ylabel('NGSC Values')
plt.show()

plt.bar(x,y)
plt.xlabel('Nodes')
plt.ylabel('NGSC Values')
plt.show()
# Out:
# NGSC Values: {'24325': 76.9, '24394': 796.3999999999999, '40517': 745.5, '58507': 119.8, '3737': 465.2999999999999, '3905': 32.8, '7237': 66.3, '12715': 257.79999999999995, '13648': 877.3, '13659': 191.4, '13664': 155.7, '14304': 110.6, '14823': 383.49999999999994, '17370': 544.1999999999999, '18956': 646.0999999999999, '19615': 974.1999999999999, '19660': 484.89999999999986, '21669': 660.8, '23106': 204.1, '24832': 85.8, '26021': 345.0, '26363': 109.0, '28240': 308.20000000000005, '35376': 55.39999999999999, '35424': 650.2, '36383': 348.79999999999995, '36860': 818.4000000000001, '37616': 322.3, '37932': 369.1999999999999, '39984': 166.29999999999995, '41687': 610.3999999999999, '44934': 683.7, '48192': 719.1, '51464': 262.99999999999994, '55079': 236.39999999999998, '59077': 967.1999999999996, '59471': 593.4999999999999, '59870': 158.4, '61742': 881.5999999999999, '61796': 270.3, '62227': 764.4, '65346': 36.5, '66689': 347.4999999999999, '67851': 142.2, '24897': 29.799999999999997, '30545': 197.5, '42653': 172.89999999999998, '1182': 23.799999999999997, '3175': 141.1, '5379': 377.5999999999999, '33426': 260.09999999999997, '34071': 474.3999999999999, '36192': 73.2, '39688': 149.49999999999997, '63113': 1014.7, '65086': 366.29999999999995, '66829': 22.799999999999997, '68041': 221.39999999999998, '554': 631.7, '3088': 398.79999999999995, '4503': 263.5, '4521': 263.5, '6142': 584.9999999999999, '9117': 125.99999999999997, '11180': 391.80000000000007, '12981': 307.9999999999999, '13769': 92.4, '20394': 660.5, '21477': 212.9, '22916': 203.50000000000003, '24295': 478.0, '28268': 141.2, '33726': 78.30000000000001, '40894': 617.3, '44594': 96.19999999999999, '45385': 583.1, '46139': 573.3, '49541': 464.5999999999999, '50970': 111.99999999999999, '53159': 243.8, '55835': 559.1999999999999, '56948': 336.0, '57628': 60.699999999999996, '60251': 148.20000000000002, '60797': 280.5, '67012': 234.49999999999994, '1441': 639.8999999999997, '3306': 472.40000000000003, '15089': 97.0, '22990': 104.4, '25318': 63.099999999999994, '25406': 21.099999999999998, '25750': 160.7, '25902': 169.4, '28406': 214.6, '28440': 15.399999999999999, '29941': 22.5, '33454': 429.2, '39659': 291.8, '40187': 87.0, '42018': 136.10000000000002, '59205': 79.7, '1444': 36.4, '4189': 18.9, '5338': 165.79999999999998, '12698': 18.9, '14425': 34.099999999999994, '15946': 209.5, '19172': 34.1, '22014': 90.8, '29017': 126.00000000000001, '30982': 101.7, '34121': 149.79999999999998, '35725': 239.89999999999998, '35863': 107.79999999999998, '40691': 58.89999999999999, '41588': 212.2, '45556': 122.5, '52121': 53.5, '52622': 200.39999999999998, '56995': 108.3, '57145': 43.5, '3029': 56.6, '39076': 4.699999999999999, '57738': 366.4999999999999, '2394': 166.20000000000002, '2470': 34.099999999999994, '6975': 406.1999999999999, '17554': 141.79999999999995, '17702': 32.099999999999994, '18533': 315.79999999999995, '20532': 180.99999999999997, '22552': 601.9, '27926': 202.39999999999998, '29761': 79.39999999999999, '33137': 50.89999999999999, '34596': 205.29999999999995, '35059': 88.0, '35280': 389.39999999999986, '47226': 86.99999999999999, '54118': 93.69999999999999, '60926': 640.8000000000001, '61918': 104.8, '65338': 147.1, '66820': 428.89999999999986, '66821': 90.6, '67820': 118.89999999999999, '4070': 181.0, '17141': 193.5, '25442': 105.8, '30291': 406.70000000000005, '37380': 52.99999999999999, '46598': 148.10000000000002, '51911': 38.599999999999994, '53676': 185.90000000000003, '54556': 369.2, '57682': 82.99999999999999, '57739': 68.99999999999999, '58198': 23.699999999999996, '6466': 124.69999999999999, '9207': 383.29999999999995, '9211': 21.599999999999998, '12067': 410.29999999999995, '16164': 924.8, '17755': 203.1, '27312': 678.8000000000001, '28209': 113.6, '32800': 298.2, '36011': 45.4, '36019': 156.1, '38656': 276.59999999999997, '39723': 623.8, '54519': 360.8999999999999, '55319': 528.9999999999999, '57174': 42.2, '58769': 126.79999999999998, '64720': 146.5, '108 ...
